# %%
import random
from Crypto.Util.number import *
from secrets import flag



def get_happy_prime():    while 1:
        p = int("".join([random.choice("123") for _ in range(512)]))
        q = int("".join([random.choice("567") for _ in range(512)]))
        if isPrime(p) and isPrime(q):
            return (p,q)

m = bytes_to_long(flag)
p ,q= get_happy_prime()
n = p * q
e = 65537
print(n)
print(pow(m, e, n))
# ...
# ...

# %%
......
# Out:
# True

# %%
......
# Out:
# True

# %%
m="..."
temp1=0
temp2=0
i=0
while(i!=0):
    if(((temp1+1*(10**i))*(temp2+5*(10**i))-int(m[1022-2*i:]))%(10**(i+1))==0):
        temp1=temp1+1*(10**i)
        temp2=temp2+5*(10**i)
        i=i+1
        continue

    if(((temp1+1*(10**i))*(temp2+6*(10**i))-int(m[1022-2*i:]))%(10**(i+1))==0):
        temp1=temp1+1*(10**i)
        temp2=temp2+6*(10**i)
        i=i+1
        continue

    if(((temp1+1*(10**i))*(temp2+7*(10**i))-int(m[1022-2*i:]))%(10**(i+1))==0):
        temp1=temp1+1*(10**i)
        temp2=temp2+7*(10**i)
        i=i+1
        continue
        
    if(((temp1+2*(10**i))*(temp2+5*(10**i))-int(m[1022-2*i:]))%(10**(i+1))==0):
        temp1=temp1+2*(10**i)
        temp2=temp2+5*(10**i)
        i=i+1
        continue
        
    if(((temp1+2*(10**i))*(temp2+6*(10**i))-int(m[1022-2*i:]))%(10**(i+1))==0):
        temp1=temp1+2*(10**i)
        temp2=temp2+6*(10**i)
        i=i+1
        continue
        
    if(((temp1+2*(10**i))*(temp2+7*(10**i))-int(m[1022-2*i:]))%(10**(i+1))==0):
        temp1=temp1+2*(10**i)
        temp2=temp2+7*(10**i)
        i=i+1
        continue
    if(((temp1+3*(10**i))*(temp2+5*(10**i))-int(m[1022-2*i:]))%(10**(i+1))==0):
        temp1=temp1+3*(10**i)
        temp2=temp2+5*(10**i)
        i=i+1
        continue
        
    if(((temp1+3*(10**i))*(temp2+6*(10**i))-int(m[1022-2*i:]))%(10**(i+1))==0):
        temp1=temp1+3*(10**i)
        temp2=temp2+6*(10**i)
        i=i+1
        continue
        
    if(((temp1+3*(10**i))*(temp2+7*(10**i))-int(m[1022-2*i:]))%(10**(i+1))==0):
        temp1=temp1+3*(10**i)
        temp2=temp2+7*(10**i)
        i=i+1
        continue
        
print(temp1)
print(temp2)

# %%
m="..."
temp1=3
temp2=7
i=1
while(i!=5):
    if(str((int('1'+str(temp1)))*(int('5'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('1'+str(temp1))
        temp2=int('5'+str(temp2))
        i=i+1
        continue
        
    if(str((int('1'+str(temp1)))*(int('6'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('1'+str(temp1))
        temp2=int('6'+str(temp2))
        i=i+1
        continue         
  
    if(str((int('1'+str(temp1)))*(int('7'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('1'+str(temp1))
        temp2=int('7'+str(temp2))
        i=i+1
        continue      
        
    if(str((int('2'+str(temp1)))*(int('5'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('2'+str(temp1))
        temp2=int('5'+str(temp2))
        i=i+1
        continue                  
   
    if(str((int('2'+str(temp1)))*(int('6'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('2'+str(temp1))
        temp2=int('6'+str(temp2))
        i=i+1
        continue                        
        
    if(str((int('2'+str(temp1)))*(int('7'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('2'+str(temp1))
        temp2=int('7'+str(temp2))
        i=i+1
        continue                    
        
    if(str((int('3'+str(temp1)))*(int('5'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('3'+str(temp1))
        temp2=int('5'+str(temp2))
        i=i+1
        continue
        
    if(str((int('3'+str(temp1)))*(int('6'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('3'+str(temp1))
        temp2=int('6'+str(temp2))
        i=i+1
        continue
        
    if(str((int('3'+str(temp1)))*(int('7'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('3'+str(temp1))
        temp2=int('7'+str(temp2))
        i=i+1
        continue      

print(temp1)
print(temp2)
# Out:
# 11113
# 55677

# %%
m="..."
#temp1=3
#temp2=7
def dfs(i,temp1,temp2):
    flag=False
    if(str((int('1'+str(temp1)))*(int('5'+str(temp2))))[-i-1:]==(m[-i-1:])):
        t1=int('1'+str(temp1))
        t2=int('5'+str(temp2))
        i=i+1
        flag=True
        dfs(i,t1,t2)
        i=i-1
        
    if(str((int('1'+str(temp1)))*(int('6'+str(temp2))))[-i-1:]==(m[-i-1:])):
        t1=int('1'+str(temp1))
        t2=int('6'+str(temp2))
        i=i+1
        flag=True
        dfs(i,t1,t2)
        i=i-1      
  
    if(str((int('1'+str(temp1)))*(int('7'+str(temp2))))[-i-1:]==(m[-i-1:])):
        t1=int('1'+str(temp1))
        t2=int('7'+str(temp2))
        i=i+1
        flag=True
        dfs(i,t1,t2)
        i=i-1     
        
    if(str((int('2'+str(temp1)))*(int('5'+str(temp2))))[-i-1:]==(m[-i-1:])):
        t1=int('2'+str(temp1))
        t2=int('5'+str(temp2))
        i=i+1
        flag=True
        dfs(i,t1,t2)
        i=i-1                 
   
    if(str((int('2'+str(temp1)))*(int('6'+str(temp2))))[-i-1:]==(m[-i-1:])):
        t1=int('2'+str(temp1))
        t2=int('6'+str(temp2))
        i=i+1
        flag=True
        dfs(i,t1,t2)
        i=i-1                     
        
    if(str((int('2'+str(temp1)))*(int('7'+str(temp2))))[-i-1:]==(m[-i-1:])):
        t1=int('2'+str(temp1))
        t2=int('7'+str(temp2))
        i=i+1
        flag=True
        dfs(i,t1,t2)
        i=i-1                 
        
    if(str((int('3'+str(temp1)))*(int('5'+str(temp2))))[-i-1:]==(m[-i-1:])):
        t1=int('3'+str(temp1))
        t2=int('5'+str(temp2))
        i=i+1
        flag=True
        dfs(i,t1,t2)
        i=i-1
        
    if(str((int('3'+str(temp1)))*(int('6'+str(temp2))))[-i-1:]==(m[-i-1:])):
        t1=int('3'+str(temp1))
        t2=int('6'+str(temp2))
        i=i+1
        flag=True
        dfs(i,t1,t2)
        i=i-1
        
    if(str((int('3'+str(temp1)))*(int('7'+str(temp2))))[-i-1:]==(m[-i-1:])):
        t1=int('3'+str(temp1))
        t2=int('7'+str(temp2))
        i=i+1
        flag=True
        dfs(i,t1,t2)
        i=i-1
    if(i==512):
        print(temp1,temp2)
        return
    if(flag==False):
        return
'''
while(i!=2):
    if(str((int('1'+str(temp1)))*(int('5'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('1'+str(temp1))
        temp2=int('5'+str(temp2))
        i=i+1
        continue
        
    if(str((int('1'+str(temp1)))*(int('6'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('1'+str(temp1))
        temp2=int('6'+str(temp2))
        i=i+1
        continue         
  
    if(str((int('1'+str(temp1)))*(int('7'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('1'+str(temp1))
        temp2=int('7'+str(temp2))
        i=i+1
        continue      
        
    if(str((int('2'+str(temp1)))*(int('5'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('2'+str(temp1))
        temp2=int('5'+str(temp2))
        i=i+1
        continue                  
   
    if(str((int('2'+str(temp1)))*(int('6'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('2'+str(temp1))
        temp2=int('6'+str(temp2))
        i=i+1
        continue                        
        
    if(str((int('2'+str(temp1)))*(int('7'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('2'+str(temp1))
        temp2=int('7'+str(temp2))
        i=i+1
        continue                    
        
    if(str((int('3'+str(temp1)))*(int('5'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('3'+str(temp1))
        temp2=int('5'+str(temp2))
        i=i+1
        continue
        
    if(str((int('3'+str(temp1)))*(int('6'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('3'+str(temp1))
        temp2=int('6'+str(temp2))
        i=i+1
        continue
        
    if(str((int('3'+str(temp1)))*(int('7'+str(temp2))))[-i-1:]==(m[-i-1:])):
        temp1=int('3'+str(temp1))
        temp2=int('7'+str(temp2))
        i=i+1
        continue      
'''
dfs(1,3,7)
# Out:
# ... ...
# ... ...
# ... ...
# ... ...
# ... ...
# ... ...
# ... ...
# ... ...
# ... ...

# %%
...*...
# Out:
# ...

# %%
...*...
# Out:
# ...

# %%
...*...
# Out:
# ...

# %%
...*...
# Out:
# ...

# %%
... ...

# %%
... ...

# %%
... ...

# %%
... ...

# %%
... ...

# %%
......
# Out:
# True

# %%
pip install flag
# Out:
# Collecting flag
#   Obtaining dependency information for flag from https://files.pythonhosted.org/packages/95/9d/2343afdea09ff2a2555fa0760ba115123c4e2b7fe60dc53fda85ddfe49d6/Flag-0.1.1-py2.py3-none-any.whl.metadata
#   Downloading Flag-0.1.1-py2.py3-none-any.whl.metadata (624 bytes)
# Downloading Flag-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Installing collected packages: flag
# Successfully installed flag-0.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from gmpy2 import *
import libnum
import gmpy2
import random
from Crypto.Util.number import *


p=...
q=...
phi=(p-1)*(q-1)
e=65537
c=...
d=invert(e,phi)
n=...
m=pow(c,d,n)
print(m)
flag=long_to_bytes(m)
print(flag)
# Out:
# 333424612234389655182834646284826466134955541485682712429615898505815567646841006495049305026834782360253542910336093909097270666086880990931329073716985270756885255172221
# b'XYCTF{7f4b2241951976ce5ef6df44503209059997e5085d1bc21f6bef4d9effb29fd0}'
